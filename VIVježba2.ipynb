# %% [markdown]
# <a href="https://colab.research.google.com/github/AnesCenanovic/Vje-ta-kaInteligencija/blob/main/VIVje%C5%BEba2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Zadatak 1

# %% [markdown]
# a)

# %%
import numpy as np
import pandas as pd

data = pd.read_csv('/content/drive/MyDrive/VI/izvjestaj.csv')

data.head(5)
data.tail(10)
# Out:
#     id Indeks  Prisustvo Ispit1 Ispit2 Ispit1_popravni Ispit2_popravni  \
# 37  38  71-ST         10      /      /               /               /
# 38  39  54-ST         10      /      /               /               /
# 39  40  60-ST         10     10      /               /               /
# 40  41  48-ST         10      /      /               /               /
# 41  42  61-ST         10      /      /               /               /
# 42  43   1-ST         10      /      /               /               /
# 43  44  88-ST         10      /      /               /               /
# 44  45  75-ST         10      /      /            9.83            13.5
# 45  46  67-ST         10   16.5      /               /               /
# 46  47  81-ST         10   15.7   17.3               /               /
#
#     UKUPNO Ocjena
# 37   42.16      8
# 38   19.35      /
# 39   38.50      6
# 40   10.00      6
# 41   23.12      /
# 42   10.00      /
# 43   37.00      7
# 44   33.33      6
# ...

# %% [markdown]
# b)

# %%
import numpy as np
import pandas as pd

data = pd.read_csv('/content/drive/MyDrive/VI/izvjestaj.csv')

data[["Ispit1","Ispit2"]]
# Out:
#    Ispit1 Ispit2
# 0     9.4    7.5
# 1     8.5      /
# 2      17      /
# 3     7.6    4.8
# 4    10.6   12.5
# 5       /      /
# 6       /   12.5
# 7       /      /
# 8       /      /
# 9       /      /
# 10      /      /
# 11     13    7.8
# 12   15.6    7.7
# 13      /      /
# 14      /      /
# 15   12.5    7.8
# 16      /      /
# 17      /      /
# 18      /      /
# 19      /      /
# 20     14    9.7
# 21   12.5      /
# 22   10.7      /
# 23   13.6   12.5
# 24   12.5    6.5
# 25      /      /
# 26   16.6    8.7
# 27      /      /
# 28   10.8   12.5
# 29      /   12.5
# 30      /      /
# 31      /      /
# 32    7.5    1.7
# 33     10    1.5
# 34      /      /
# 35   13.3     15
# 36      /      /
# 37      /      /
# 38      /      /
# 39     10      /
# 40      /      /
# 41      /      /
# 42      /      /
# 43      /      /
# 44      /      /
# 45   16.5      /
# 46   15.7   17.3

# %% [markdown]
# c)

# %%
import numpy as np
import pandas as pd

data = pd.read_csv('/content/drive/MyDrive/VI/izvjestaj.csv')

data.loc[data['Prisustvo'] == 0]
# Out:
#     id Indeks  Prisustvo Ispit1 Ispit2 Ispit1_popravni Ispit2_popravni  \
# 3    4  79-ST          0    7.6    4.8               /               /
# 5    6  78-ST          0      /      /           13.08           12.83
# 8    9  83-ST          0      /      /               /               /
# 22  23  74-ST          0   10.7      /           14.58            11.7
# 28  29  95-ST          0   10.8   12.5            7.25               /
# 31  32  41-ST          0      /      /               /               /
# 32  33  17-ST          0    7.5    1.7            2.33               /
# 33  34  82-ST          0     10    1.5               /               /
# 34  35  15-ST          0      /      /               /               /
#
#     UKUPNO Ocjena
# 3    12.40      /
# 5    25.91      6
# 8     0.00      /
# 22   27.08      /
# 28   23.50      /
# 31    5.87      /
# 32    9.20      /
# 33   16.00      /
# 34    0.00      /

# %% [markdown]
# d)

# %%
import numpy as np
import pandas as pd

data = pd.read_csv('/content/drive/MyDrive/VI/izvjestaj.csv')

data[data['Ocjena'] >= '8'][['Indeks','UKUPNO','Ocjena']]
# Out:
#    Indeks  UKUPNO Ocjena
# 2   69-ST   39.50      9
# 6   93-ST   35.17      8
# 7   68-ST   50.00      9
# 9   92-ST   42.06      9
# 10  65-ST   43.19      8
# 12  90-ST   39.90      8
# 13  97-ST   41.05      9
# 14  84-ST   43.56      9
# 16  91-ST   43.48      9
# 19  96-ST   41.40      8
# 20  66-ST   40.00      8
# 21  62-ST   42.00      8
# 25  80-ST   39.45      8
# 26  63-ST   46.60      8
# 35  64-ST   38.30      8
# 37  71-ST   42.16      8
# 46  81-ST   43.00      8

# %% [markdown]
# e)

# %%
import numpy as np
import pandas as pd

data = pd.read_csv('/content/drive/MyDrive/VI/izvjestaj.csv')

data.replace('/', np.nan, inplace=True)
data
# Out:
#     id Indeks  Prisustvo Ispit1 Ispit2 Ispit1_popravni Ispit2_popravni  \
# 0    1  94-ST         10    9.4    7.5           12.08           13.73
# 1    2  77-ST         10    8.5    NaN             NaN             NaN
# 2    3  69-ST         10     17    NaN             NaN             NaN
# 3    4  79-ST          0    7.6    4.8             NaN             NaN
# 4    5  89-ST         10   10.6   12.5           12.58             NaN
# 5    6  78-ST          0    NaN    NaN           13.08           12.83
# 6    7  93-ST         10    NaN   12.5           12.67             NaN
# 7    8  68-ST         10    NaN    NaN             NaN             NaN
# 8    9  83-ST          0    NaN    NaN             NaN             NaN
# 9   10  92-ST         10    NaN    NaN             NaN             NaN
# 10  11  65-ST         10    NaN    NaN             NaN             NaN
# 11  12  70-ST         10     13    7.8             NaN            16.3
# ...

# %% [markdown]
# f)

# %%
import numpy as np
import pandas as pd

data = pd.read_csv('/content/drive/MyDrive/VI/izvjestaj.csv')

data.replace('/', np.nan, inplace=True)
data.dropna(subset=['Ocjena'], inplace=True)

data
# Out:
#     id Indeks  Prisustvo Ispit1 Ispit2 Ispit1_popravni Ispit2_popravni  \
# 0    1  94-ST         10    9.4    7.5           12.08           13.73
# 1    2  77-ST         10    8.5    NaN             NaN             NaN
# 2    3  69-ST         10     17    NaN             NaN             NaN
# 4    5  89-ST         10   10.6   12.5           12.58             NaN
# 5    6  78-ST          0    NaN    NaN           13.08           12.83
# 6    7  93-ST         10    NaN   12.5           12.67             NaN
# 7    8  68-ST         10    NaN    NaN             NaN             NaN
# 9   10  92-ST         10    NaN    NaN             NaN             NaN
# 10  11  65-ST         10    NaN    NaN             NaN             NaN
# 11  12  70-ST         10     13    7.8             NaN            16.3
# 12  13  90-ST         10   15.6    7.7             NaN            14.3
# 13  14  97-ST         10    NaN    NaN             NaN             NaN
# ...

# %% [markdown]
# g)

# %%
import numpy as np
import pandas as pd

data = pd.read_csv('/content/drive/MyDrive/VI/izvjestaj.csv')

data.replace('/', np.nan, inplace=True)

ispit1 = ['Ispit1','Ispit1_popravni']
data[ispit1] = data[ispit1].astype(float)

data['Ispit1_final'] = data[['Ispit1','Ispit1_popravni']].max(axis=1)

data
# Out:
#     id Indeks  Prisustvo  Ispit1 Ispit2  Ispit1_popravni Ispit2_popravni  \
# 0    1  94-ST         10     9.4    7.5            12.08           13.73
# 1    2  77-ST         10     8.5    NaN              NaN             NaN
# 2    3  69-ST         10    17.0    NaN              NaN             NaN
# 3    4  79-ST          0     7.6    4.8              NaN             NaN
# 4    5  89-ST         10    10.6   12.5            12.58             NaN
# 5    6  78-ST          0     NaN    NaN            13.08           12.83
# 6    7  93-ST         10     NaN   12.5            12.67             NaN
# 7    8  68-ST         10     NaN    NaN              NaN             NaN
# 8    9  83-ST          0     NaN    NaN              NaN             NaN
# 9   10  92-ST         10     NaN    NaN              NaN             NaN
# 10  11  65-ST         10     NaN    NaN              NaN             NaN
# 11  12  70-ST         10    13.0    7.8              NaN            16.3
# ...

# %% [markdown]
# h)

# %%
import numpy as np
import pandas as pd

data = pd.read_csv('/content/drive/MyDrive/VI/izvjestaj.csv')

data.replace('/', np.nan, inplace=True)

ispit2 = ['Ispit2','Ispit2_popravni']
data[ispit2] = data[ispit2].astype(float)

data['Ispit2_final'] = data[['Ispit2','Ispit2_popravni']].max(axis=1)

data
# Out:
#     id Indeks  Prisustvo Ispit1  Ispit2 Ispit1_popravni  Ispit2_popravni  \
# 0    1  94-ST         10    9.4     7.5           12.08            13.73
# 1    2  77-ST         10    8.5     NaN             NaN              NaN
# 2    3  69-ST         10     17     NaN             NaN              NaN
# 3    4  79-ST          0    7.6     4.8             NaN              NaN
# 4    5  89-ST         10   10.6    12.5           12.58              NaN
# 5    6  78-ST          0    NaN     NaN           13.08            12.83
# 6    7  93-ST         10    NaN    12.5           12.67              NaN
# 7    8  68-ST         10    NaN     NaN             NaN              NaN
# 8    9  83-ST          0    NaN     NaN             NaN              NaN
# 9   10  92-ST         10    NaN     NaN             NaN              NaN
# 10  11  65-ST         10    NaN     NaN             NaN              NaN
# 11  12  70-ST         10     13     7.8             NaN            16.30
# ...

# %% [markdown]
# i)

# %%
import numpy as np
import pandas as pd

data = pd.read_csv('/content/drive/MyDrive/VI/izvjestaj.csv')

data.replace('/', np.nan, inplace=True)

ispit1 = ['Ispit1','Ispit1_popravni']
data[ispit1] = data[ispit1].astype(float)

data['Ispit1_final'] = data[['Ispit1','Ispit1_popravni']].max(axis=1)

ispit2 = ['Ispit2','Ispit2_popravni']
data[ispit2] = data[ispit2].astype(float)

data['Ispit2_final'] = data[['Ispit2','Ispit2_popravni']].max(axis=1)

data.drop(columns=['Ispit1','Ispit2','Ispit1_popravni','Ispit2_popravni'],inplace=True)

data
# Out:
#     id Indeks  Prisustvo  UKUPNO Ocjena  Ispit1_final  Ispit2_final
# 0    1  94-ST         10   35.81      7         12.08         13.73
# 1    2  77-ST         10   35.50      7          8.50           NaN
# 2    3  69-ST         10   39.50      9         17.00           NaN
# 3    4  79-ST          0   12.40    NaN          7.60          4.80
# 4    5  89-ST         10   35.08      6         12.58         12.50
# 5    6  78-ST          0   25.91      6         13.08         12.83
# 6    7  93-ST         10   35.17      8         12.67         12.50
# 7    8  68-ST         10   50.00      9           NaN           NaN
# 8    9  83-ST          0    0.00    NaN           NaN           NaN
# 9   10  92-ST         10   42.06      9           NaN           NaN
# 10  11  65-ST         10   43.19      8           NaN           NaN
# 11  12  70-ST         10   39.30      7         13.00         16.30
# 12  13  90-ST         10   39.90      8         15.60         14.30
# ...

# %% [markdown]
# j)

# %%
import numpy as np
import pandas as pd

data = pd.read_csv('/content/drive/MyDrive/VI/izvjestaj.csv')

data.replace('/', np.nan, inplace=True)

ispit1 = ['Ispit1','Ispit1_popravni']
data[ispit1] = data[ispit1].astype(float)

data['Ispit1_final'] = data[['Ispit1','Ispit1_popravni']].max(axis=1)

ispit2 = ['Ispit2','Ispit2_popravni']
data[ispit2] = data[ispit2].astype(float)

data['Ispit2_final'] = data[['Ispit2','Ispit2_popravni']].max(axis=1)

data.drop(columns=['Ispit1','Ispit2','Ispit1_popravni','Ispit2_popravni'],inplace=True)

data.to_csv('izvjestaj_modificirano.csv', sep=';', index=False)

data
# Out:
#     id Indeks  Prisustvo  UKUPNO Ocjena  Ispit1_final  Ispit2_final
# 0    1  94-ST         10   35.81      7         12.08         13.73
# 1    2  77-ST         10   35.50      7          8.50           NaN
# 2    3  69-ST         10   39.50      9         17.00           NaN
# 3    4  79-ST          0   12.40    NaN          7.60          4.80
# 4    5  89-ST         10   35.08      6         12.58         12.50
# 5    6  78-ST          0   25.91      6         13.08         12.83
# 6    7  93-ST         10   35.17      8         12.67         12.50
# 7    8  68-ST         10   50.00      9           NaN           NaN
# 8    9  83-ST          0    0.00    NaN           NaN           NaN
# 9   10  92-ST         10   42.06      9           NaN           NaN
# 10  11  65-ST         10   43.19      8           NaN           NaN
# 11  12  70-ST         10   39.30      7         13.00         16.30
# 12  13  90-ST         10   39.90      8         15.60         14.30
# ...

# %% [markdown]
# k)

# %%
import numpy as np
import pandas as pd
import pickle

data = pd.read_csv('/content/drive/MyDrive/VI/izvjestaj.csv')

data.replace('/', np.nan, inplace=True)

ispit1 = ['Ispit1','Ispit1_popravni']
data[ispit1] = data[ispit1].astype(float)

data['Ispit1_final'] = data[['Ispit1','Ispit1_popravni']].max(axis=1)

ispit2 = ['Ispit2','Ispit2_popravni']
data[ispit2] = data[ispit2].astype(float)

data['Ispit2_final'] = data[['Ispit2','Ispit2_popravni']].max(axis=1)

data.drop(columns=['Ispit1','Ispit2','Ispit1_popravni','Ispit2_popravni'],inplace=True)

data.to_pickle('izvjestaj_modificirano.p')

data
# Out:
#     id Indeks  Prisustvo  UKUPNO Ocjena  Ispit1_final  Ispit2_final
# 0    1  94-ST         10   35.81      7         12.08         13.73
# 1    2  77-ST         10   35.50      7          8.50           NaN
# 2    3  69-ST         10   39.50      9         17.00           NaN
# 3    4  79-ST          0   12.40    NaN          7.60          4.80
# 4    5  89-ST         10   35.08      6         12.58         12.50
# 5    6  78-ST          0   25.91      6         13.08         12.83
# 6    7  93-ST         10   35.17      8         12.67         12.50
# 7    8  68-ST         10   50.00      9           NaN           NaN
# 8    9  83-ST          0    0.00    NaN           NaN           NaN
# 9   10  92-ST         10   42.06      9           NaN           NaN
# 10  11  65-ST         10   43.19      8           NaN           NaN
# 11  12  70-ST         10   39.30      7         13.00         16.30
# 12  13  90-ST         10   39.90      8         15.60         14.30
# ...

# %% [markdown]
# Zadatak 2

# %% [markdown]
# a)

# %%
import numpy as np
import pandas as pd

data = pd.read_csv('/content/drive/MyDrive/VI/izvjestaj.csv')
data
# Out:
#     id Indeks  Prisustvo Ispit1 Ispit2 Ispit1_popravni Ispit2_popravni  \
# 0    1  94-ST         10    9.4    7.5           12.08           13.73
# 1    2  77-ST         10    8.5      /               /               /
# 2    3  69-ST         10     17      /               /               /
# 3    4  79-ST          0    7.6    4.8               /               /
# 4    5  89-ST         10   10.6   12.5           12.58               /
# 5    6  78-ST          0      /      /           13.08           12.83
# 6    7  93-ST         10      /   12.5           12.67               /
# 7    8  68-ST         10      /      /               /               /
# 8    9  83-ST          0      /      /               /               /
# 9   10  92-ST         10      /      /               /               /
# 10  11  65-ST         10      /      /               /               /
# 11  12  70-ST         10     13    7.8               /            16.3
# ...

# %% [markdown]
# b)

# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer

data = pd.read_csv('/content/drive/MyDrive/VI/izvjestaj.csv')
data.replace("/",np.nan,inplace=True)

columns=['Ispit1','Ispit2']
data[columns]=data[columns].apply(pd.to_numeric, errors='coerce')

imputer = SimpleImputer(strategy='median')

data[columns] = imputer.fit_transform(data[columns])

data
# Out:
#     id Indeks  Prisustvo  Ispit1  Ispit2 Ispit1_popravni Ispit2_popravni  \
# 0    1  94-ST         10     9.4     7.5           12.08           13.73
# 1    2  77-ST         10     8.5     8.7             NaN             NaN
# 2    3  69-ST         10    17.0     8.7             NaN             NaN
# 3    4  79-ST          0     7.6     4.8             NaN             NaN
# 4    5  89-ST         10    10.6    12.5           12.58             NaN
# 5    6  78-ST          0    12.5     8.7           13.08           12.83
# 6    7  93-ST         10    12.5    12.5           12.67             NaN
# 7    8  68-ST         10    12.5     8.7             NaN             NaN
# 8    9  83-ST          0    12.5     8.7             NaN             NaN
# 9   10  92-ST         10    12.5     8.7             NaN             NaN
# 10  11  65-ST         10    12.5     8.7             NaN             NaN
# 11  12  70-ST         10    13.0     7.8             NaN            16.3
# ...

# %% [markdown]
# c)

# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer

data = pd.read_csv('/content/drive/MyDrive/VI/izvjestaj.csv')
data.replace("/",np.nan,inplace=True)

columns=['Ispit1_popravni','Ispit2_popravni']
data[columns]=data[columns].apply(pd.to_numeric, errors='coerce')

imputer = SimpleImputer(strategy='mean')

data[columns] = imputer.fit_transform(data[columns])

data
# Out:
#     id Indeks  Prisustvo Ispit1 Ispit2  Ispit1_popravni  Ispit2_popravni  \
# 0    1  94-ST         10    9.4    7.5           12.080        13.730000
# 1    2  77-ST         10    8.5    NaN           10.657        14.662727
# 2    3  69-ST         10     17    NaN           10.657        14.662727
# 3    4  79-ST          0    7.6    4.8           10.657        14.662727
# 4    5  89-ST         10   10.6   12.5           12.580        14.662727
# 5    6  78-ST          0    NaN    NaN           13.080        12.830000
# 6    7  93-ST         10    NaN   12.5           12.670        14.662727
# 7    8  68-ST         10    NaN    NaN           10.657        14.662727
# 8    9  83-ST          0    NaN    NaN           10.657        14.662727
# 9   10  92-ST         10    NaN    NaN           10.657        14.662727
# 10  11  65-ST         10    NaN    NaN           10.657        14.662727
# 11  12  70-ST         10     13    7.8           10.657        16.300000
# ...

# %% [markdown]
# d)

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import scale
from sklearn.impute import SimpleImputer

data = pd.read_csv('/content/drive/MyDrive/VI/izvjestaj.csv')
data.replace("/",np.nan,inplace=True)

columns=['Ispit1','Ispit2']
data[columns]=data[columns].apply(pd.to_numeric, errors='coerce')

imputer = SimpleImputer(strategy='mean')


data[columns] = scale(data[columns])

data
# Out:
#     id Indeks  Prisustvo    Ispit1    Ispit2 Ispit1_popravni Ispit2_popravni  \
# 0    1  94-ST         10 -1.003417 -0.430380           12.08           13.73
# 1    2  77-ST         10 -1.316882       NaN             NaN             NaN
# 2    3  69-ST         10  1.643614       NaN             NaN             NaN
# 3    4  79-ST          0 -1.630346 -1.067619             NaN             NaN
# 4    5  89-ST         10 -0.585465  0.749693           12.58             NaN
# 5    6  78-ST          0       NaN       NaN           13.08           12.83
# 6    7  93-ST         10       NaN  0.749693           12.67             NaN
# 7    8  68-ST         10       NaN       NaN             NaN             NaN
# 8    9  83-ST          0       NaN       NaN             NaN             NaN
# 9   10  92-ST         10       NaN       NaN             NaN             NaN
# 10  11  65-ST         10       NaN       NaN             NaN             NaN
# ...

# %% [markdown]
# e)

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer

data = pd.read_csv('/content/drive/MyDrive/VI/izvjestaj.csv')
data.replace("/",np.nan,inplace=True)

columns=['Ispit1','Ispit2']
data[columns]=data[columns].apply(pd.to_numeric, errors='coerce')

mn = MinMaxScaler()

data[columns] = mn.fit_transform(data[columns])

data
# Out:
#     id Indeks  Prisustvo    Ispit1    Ispit2 Ispit1_popravni Ispit2_popravni  \
# 0    1  94-ST         10  0.200000  0.379747           12.08           13.73
# 1    2  77-ST         10  0.105263       NaN             NaN             NaN
# 2    3  69-ST         10  1.000000       NaN             NaN             NaN
# 3    4  79-ST          0  0.010526  0.208861             NaN             NaN
# 4    5  89-ST         10  0.326316  0.696203           12.58             NaN
# 5    6  78-ST          0       NaN       NaN           13.08           12.83
# 6    7  93-ST         10       NaN  0.696203           12.67             NaN
# 7    8  68-ST         10       NaN       NaN             NaN             NaN
# 8    9  83-ST          0       NaN       NaN             NaN             NaN
# 9   10  92-ST         10       NaN       NaN             NaN             NaN
# 10  11  65-ST         10       NaN       NaN             NaN             NaN
# ...

# %% [markdown]
# f)

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer

data = pd.read_csv('/content/drive/MyDrive/VI/izvjestaj.csv')
data.replace("/",np.nan,inplace=True)

columns=['Ispit1','Ispit2']
data[columns]=data[columns].apply(pd.to_numeric, errors='coerce')

mn = MinMaxScaler()

data[columns] = mn.fit_transform(data[columns])

data.replace(np.nan,0,inplace=True)

data
# Out:
#     id Indeks  Prisustvo    Ispit1    Ispit2 Ispit1_popravni Ispit2_popravni  \
# 0    1  94-ST         10  0.200000  0.379747           12.08           13.73
# 1    2  77-ST         10  0.105263  0.000000               0               0
# 2    3  69-ST         10  1.000000  0.000000               0               0
# 3    4  79-ST          0  0.010526  0.208861               0               0
# 4    5  89-ST         10  0.326316  0.696203           12.58               0
# 5    6  78-ST          0  0.000000  0.000000           13.08           12.83
# 6    7  93-ST         10  0.000000  0.696203           12.67               0
# 7    8  68-ST         10  0.000000  0.000000               0               0
# 8    9  83-ST          0  0.000000  0.000000               0               0
# 9   10  92-ST         10  0.000000  0.000000               0               0
# 10  11  65-ST         10  0.000000  0.000000               0               0
# ...

# %% [markdown]
# g)

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer

data = pd.read_csv('/content/drive/MyDrive/VI/izvjestaj.csv')
data.replace("/",np.nan,inplace=True)

columns=['Ispit1','Ispit2']
data[columns]=data[columns].apply(pd.to_numeric, errors='coerce')

mn = MinMaxScaler()

data[columns] = mn.fit_transform(data[columns])

data.replace(np.nan,0,inplace=True)

ocjene = data['Ocjena']

data.drop(columns=['Ocjena'],inplace=True)

print(ocjene)

data
# Out:
# 0     7
# 1     7
# 2     9
# 3     0
# 4     6
# 5     6
# 6     8
# 7     9
# 8     0
# 9     9
# 10    8
# 11    7
# 12    8
# 13    9
# 14    9
# 15    0
# 16    9
# 17    7
# 18    0
# 19    8
# 20    8
# 21    8
# 22    0
# 23    6
# 24    7
# 25    8
# 26    8
# 27    0
# 28    0
# 29    7
# 30    0
# 31    0
# 32    0
# 33    0
# 34    0
# 35    8
# 36    0
# 37    8
# 38    0
# 39    6
# 40    6
# 41    0
# 42    0
# 43    7
# 44    6
# 45    7
# 46    8
# Name: Ocjena, dtype: object
#     id Indeks  Prisustvo    Ispit1    Ispit2 Ispit1_popravni Ispit2_popravni  \
# 0    1  94-ST         10  0.200000  0.379747           12.08           13.73
# 1    2  77-ST         10  0.105263  0.000000               0               0
# 2    3  69-ST         10  1.000000  0.000000               0               0
# 3    4  79-ST          0  0.010526  0.208861               0               0
# 4    5  89-ST         10  0.326316  0.696203           12.58               0
# ...

# %% [markdown]
# h)

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer

data = pd.read_csv('/content/drive/MyDrive/VI/izvjestaj.csv')
data.replace("/",np.nan,inplace=True)

columns=['Ispit1','Ispit2']
data[columns]=data[columns].apply(pd.to_numeric, errors='coerce')

mn = MinMaxScaler()

data[columns] = mn.fit_transform(data[columns])

data.replace(np.nan,0,inplace=True)

ocjene = data['Ocjena']

data.drop(columns=['Ocjena'],inplace=True)

data_numpy = data.to_numpy()
ocjene_numpy = ocjene.to_numpy()

print(ocjene_numpy)
print(data_numpy)
# Out:
# ['7' '7' '9' 0 '6' '6' '8' '9' 0 '9' '8' '7' '8' '9' '9' 0 '9' '7' 0 '8'
#  '8' '8' 0 '6' '7' '8' '8' 0 0 '7' 0 0 0 0 0 '8' 0 '8' 0 '6' '6' 0 0 '7'
#  '6' '7' '8']
# [[1 '94-ST' 10 0.19999999999999996 0.3797468354430379 '12.08' '13.73'
#   35.81]
#  [2 '77-ST' 10 0.10526315789473673 0.0 0 0 35.5]
#  [3 '69-ST' 10 0.9999999999999998 0.0 0 0 39.5]
#  [4 '79-ST' 0 0.010526315789473606 0.20886075949367086 0 0 12.4]
#  [5 '89-ST' 10 0.3263157894736841 0.6962025316455696 '12.58' 0 35.08]
#  [6 '78-ST' 0 0.0 0.0 '13.08' '12.83' 25.91]
#  [7 '93-ST' 10 0.0 0.6962025316455696 '12.67' 0 35.17]
#  [8 '68-ST' 10 0.0 0.0 0 0 50.0]
#  [9 '83-ST' 0 0.0 0.0 0 0 0.0]
#  [10 '92-ST' 10 0.0 0.0 0 0 42.06]
#  [11 '65-ST' 10 0.0 0.0 0 0 43.19]
#  [12 '70-ST' 10 0.5789473684210524 0.3987341772151898 0 '16.3' 39.3]
#  [13 '90-ST' 10 0.8526315789473682 0.3924050632911392 0 '14.3' 39.9]
#  [14 '97-ST' 10 0.0 0.0 0 0 41.05]
#  [15 '84-ST' 10 0.0 0.0 0 0 43.56]
# ...

# %% [markdown]
# i)

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split

data = pd.read_csv('/content/drive/MyDrive/VI/izvjestaj.csv')
data.replace("/",np.nan,inplace=True)

columns=['Ispit1','Ispit2']
data[columns]=data[columns].apply(pd.to_numeric, errors='coerce')

mn = MinMaxScaler()

data[columns] = mn.fit_transform(data[columns])

data.replace(np.nan,0,inplace=True)

ocjene = data['Ocjena']

data.drop(columns=['Ocjena'],inplace=True)

data_numpy = data.to_numpy()
ocjene_numpy = ocjene.to_numpy()

X_train, X_test, Y_train, Y_test = train_test_split(data_numpy, ocjene_numpy, test_size=0.2, random_state=42 )

print("Training set shape (features):", X_train.shape)
print("Test set shape (features):", X_test.shape)
print("Training set shape (labels):", Y_train.shape)
print("Test set shape (labels):", Y_test.shape)
# Out:
# Training set shape (features): (37, 8)
# Test set shape (features): (10, 8)
# Training set shape (labels): (37,)
# Test set shape (labels): (10,)

# %% [markdown]
# Zadatak 3

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier

iris = load_iris()
X = iris.data
y = iris.target

feature_names = iris.feature_names
target_names = iris.target_names

print("Nazivi znacajki: ", feature_names)
print("Nazivi labela: ", target_names)
print("\nPrvih 5 redova X :\n ", X[:5])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 1)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)

classifier_knn = KNeighborsClassifier(n_neighbors = 31)

classifier_knn.fit(X_train,y_train)

y_pred = classifier_knn.predict(X_test)

print("Tacnost: ", metrics.accuracy_score(y_test,y_pred))
# Out:
# Nazivi znacajki:  ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# Nazivi labela:  ['setosa' 'versicolor' 'virginica']
#
# Prvih 5 redova X :
#   [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]]
# (105, 4)
# (45, 4)
# (105,)
# (45,)
# Tacnost:  0.9777777777777777

# %% [markdown]
# Zadatak 4

# %%
from keras.datasets import mnist
from keras import models
from keras import layers
from keras.utils import to_categorical

(x_train,y_train), (x_test,y_test) = mnist.load_data()

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

train_images = x_train.reshape((x_train.shape[0], 28*28))
train_images = train_images.astype('float32') / 255

test_images = x_test.reshape((x_test.shape[0], 28*28))
test_images = test_images.astype('float32') / 255

print(test_images.shape)
print(train_images.shape)

network = models.Sequential()
network.add(layers.Dense(512, activation = 'relu', input_shape = (28*28,)))
network.add(layers.Dense(10, activation='softmax'))

network.compile(optimizer='rmsprop',
loss='categorical_crossentropy',
metrics=['accuracy'])

train_labels = to_categorical(y_train)
test_labels = to_categorical(y_test)

network.fit(train_images, train_labels, epochs=5, batch_size=128)

test_loss, test_acc = network.evaluate(test_images, test_labels)
print('Tacnost za testni skup:', test_acc)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)
# (60000,)
# (10000,)
# (10000, 784)
# (60000, 784)
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8681 - loss: 0.4506
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9660 - loss: 0.1170
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9781 - loss: 0.0753
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9846 - loss: 0.0524
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9874 - loss: 0.0405
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9782 - loss: 0.0737
# Tacnost za testni skup: 0.9814000129699707
